# %% [markdown]
# # Identify models which include a complete set of variables to initialise or fine-tune the AI Aurora weather model

# %% [markdown]
# ## To do
# - [ ] Check which variables need to be adjusted (change units, geopotential height to geopotential?)
# - [ ] find or derive the static variables (land sea mask etc)

# %%
# load ESM catalogue (ESMcat) package
import esmcat as ecat

# %%
# Identify all the CMIP6 runs in catalogue with a complete variable set
df = ecat.catalogue(dataset='cmip6', 
                    Var=['tas','uas','vas','psl','ta','ua','va','hus','zg'], 
                    CMOR='Amon', 
                    complete_var_set=True)

# %%
# Get the static variables
...
